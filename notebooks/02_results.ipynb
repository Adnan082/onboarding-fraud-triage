# %% [markdown]
# # Results
#
# Reads generated artefacts only: reports/metrics.json and reports/tables/.
#
# Thin notebook: import from `src/triage`, keep no logic here, outputs stripped.

# %%
from hydra import compose, initialize_config_dir

# TODO: compose the config and import the helpers this notebook needs.
